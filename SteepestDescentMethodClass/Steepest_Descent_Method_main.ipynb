# %% [markdown]
# # 最急降下法の利用(クラス利用)
# 2変数利用場合

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/授業/2021実践演習2/')
import Steepest_Descent_Method_lib as lib
import sympy as sp

# %%
x0, x1, x2, a0 = sp.symbols('x0 x1 x2 a0')
f = 10*x1**2 +5*x1*x2 +10*(x2-3)**2 #関数f(x1,x2)
x0 = sp.Matrix([[10],[15]]) #初期値
sp.init_printing()
f
# Out:
#      2                        2
# 10⋅x₁  + 5⋅x₁⋅x₂ + 10⋅(x₂ - 3)

# %%
# コンストラクタの呼び出し
slib = lib.Steepest_Descent_Method(f, x0)

# %%
x = slib.getDescent()
print(x)
# Out:
# Matrix([[-0.800038112783867], [3.20003691760946]])
