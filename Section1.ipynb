# %%
print('Hello World!!!')
# Out:
# Hello World!!!

# %%
a = 8.9
b = 10.7
c = 1.1
if a <= b:
  if b <= c:
    print(c)
  else:
    print(b)
else:
  if a <= c:
    print(c)
  else:
    print(a)
# Out:
# 10.7

# %%
for n in range(10): #C言語 for(i = 0; i < 10; i++){}
  print(3 * n + 7)
# Out:
# 7
# 10
# 13
# 16
# 19
# 22
# 25
# 28
# 31
# 34

# %%
l = ['a', 'b', 'c', 'd', 'e']
for x in l:
  print(x)
# Out:
# a
# b
# c
# d
# e

# %%
word = ['A', 'B', 'C']
#len(word) #len(リスト) リストの長さ
for i, val in enumerate(word):
  print('index : {0}, value = {1}'.format(i, val))
# i : 要素番号, val : 値
# Out:
# index : 0, value = A
# index : 1, value = B
# index : 2, value = C

# %%
l = [i**2 for i in range(10)]
l
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
file = '/content/drive/MyDrive/講座/JSDSS/2021_データサイエンスのための数学的プログラミング入門/subject.csv'
df = pd.read_csv(file, engine='python', encoding='utf-8')
df
# Out:
#   氏名  国語  数学  英語  理科
# 0  A  95  98  90  86
# 1  B  75  82  85  88
# 2  C  55  79  92  65
# 3  D  28  46  75  50
# 4  E  45  38  72  68
# 5  F  71  90  94  86
# 6  G  85  86  78  80
